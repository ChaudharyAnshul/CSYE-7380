# %%
mcq=[{"question": "What is the primary goal of generative modeling?", "opt1": "To classify data into categories", "opt2": "To predict future values based on past data", "opt3": "To generate new data instances that resemble the training data", "opt4": "To identify patterns in unstructured data"}, {"question": "What are the two main components of a Generative Adversarial Network (GAN)?", "opt1": "Encoder and Decoder", "opt2": "Generator and Classifier", "opt3": "Generator and Discriminator", "opt4": "Discriminator and Classifier"}, {"question": "What is the role of the Generator in a GAN?", "opt1": "To classify data as real or fake", "opt2": "To generate new data instances", "opt3": "To evaluate the quality of generated data", "opt4": "To preprocess input data"}, {"question": "What is the role of the Discriminator in a GAN?", "opt1": "To generate new data instances", "opt2": "To evaluate the quality of generated data", "opt3": "To classify data as real or fake", "opt4": "To preprocess input data"}, {"question": "What type of output does the Discriminator typically produce?", "opt1": "A high-dimensional vector", "opt2": "A low-dimensional vector", "opt3": "A scalar value", "opt4": "A probability distribution"}, {"question": "How does the Discriminator provide feedback to the Generator?", "opt1": "By providing the ground truth labels", "opt2": "By assigning a score indicating the realism of generated data", "opt3": "By directly modifying the Generator's parameters", "opt4": "By calculating the loss function"}, {"question": "What is the concept of 'adversarial' in the context of GANs?", "opt1": "The two networks (Generator and Discriminator) compete against each other", "opt2": "The model is trained on a dataset of adversarial examples", "opt3": "The model is designed to be robust against adversarial attacks", "opt4": "The model uses adversarial examples to improve its performance"}, {"question": "What is the primary goal of training a GAN?", "opt1": "To optimize the parameters of the Discriminator", "opt2": "To maximize the accuracy of both the Generator and Discriminator", "opt3": "To find the optimal parameters of the Generator", "opt4": "To minimize the loss function"}, {"question": "What is 'hallucination' in the context of generative models?", "opt1": "When the model generates nonsensical or grammatically incorrect outputs", "opt2": "When the model generates outputs that are factually incorrect", "opt3": "When the model fails to generate any output", "opt4": "All of the above"}, {"question": "What is a common way to evaluate GAN performance?", "opt1": "By calculating the accuracy of the Discriminator", "opt2": "By comparing the generated data to the real data using metrics", "opt3": "By analyzing the loss function values", "opt4": "All of the above"}, {"question": "What is a primary application of GANs?", "opt1": "Image generation", "opt2": "Text generation", "opt3": "Video generation", "opt4": "All of the above"}, {"question": "What kind of data is often used to provide input noise for the generator in a GAN?", "opt1": "Real data samples", "opt2": "Random noise vectors", "opt3": "Labelled data", "opt4": "Pre-trained embeddings"}, {"question": "What is a potential limitation of GANs?", "opt1": "The training process is computationally expensive", "opt2": "They are prone to mode collapse", "opt3": "They can be difficult to train and tune", "opt4": "All of the above"}]
answers=[{"question": "What is the primary goal of generative modeling?", "answer": "To generate new data instances that resemble the training data", "explanation": "Generative models aim to learn the underlying data distribution to create new, similar data points."}, {"question": "What are the two main components of a Generative Adversarial Network (GAN)?", "answer": "Generator and Discriminator", "explanation": "GANs consist of a Generator, which creates new data, and a Discriminator, which evaluates the realism of the generated data."}, {"question": "What is the role of the Generator in a GAN?", "answer": "To generate new data instances", "explanation": "The Generator's primary function is to create new data instances that resemble the training data."}, {"question": "What is the role of the Discriminator in a GAN?", "answer": "To classify data as real or fake", "explanation": "The Discriminator's role is to distinguish between real data samples and those generated by the Generator."}, {"question": "What type of output does the Discriminator typically produce?", "answer": "A scalar value", "explanation": "The Discriminator usually outputs a scalar value representing a probability (often between 0 and 1) indicating the likelihood of the input being real."}, {"question": "How does the Discriminator provide feedback to the Generator?", "answer": "By assigning a score indicating the realism of generated data", "explanation": "The Discriminator provides feedback to the Generator by assigning scores to the generated data, indicating how realistic the data is."}, {"question": "What is the concept of 'adversarial' in the context of GANs?", "answer": "The two networks (Generator and Discriminator) compete against each other", "explanation": "The 'adversarial' nature of GANs refers to the competitive training process where the Generator and Discriminator work against each other, constantly improving."}, {"question": "What is the primary goal of training a GAN?", "answer": "To find the optimal parameters of the Generator", "explanation": "The goal of GAN training is to find the optimal parameters for the Generator, enabling it to produce highly realistic data that can fool the Discriminator."}, {"question": "What is 'hallucination' in the context of generative models?", "answer": "All of the above", "explanation": "Hallucination encompasses generating nonsensical, factually incorrect, or grammatically flawed outputs"}, {"question": "What is a common way to evaluate GAN performance?", "answer": "All of the above", "explanation": "GAN performance can be assessed by various metrics, focusing on the Discriminator's accuracy, comparison of generated and real data, and analysis of the loss function."}, {"question": "What is a primary application of GANs?", "answer": "All of the above", "explanation": "GANs have wide applications across various domains like image generation, text generation and video generation."}, {"question": "What kind of data is often used to provide input noise for the generator in a GAN?", "answer": "Random noise vectors", "explanation": "The Generator uses random noise as input, combined with any other inputs to generate new data instances."}, {"question": "What is a potential limitation of GANs?", "answer": "All of the above", "explanation": "GAN training is computationally expensive, can suffer from mode collapse where the model generates only a limited range of outputs and is notoriously difficult to train and tune."}]

# %%
len(mcq), len(answers)
# Out:
# (13, 13)

# %%
mcq[0]
# Out:
# {'question': 'What is the primary goal of generative modeling?',
#  'opt1': 'To classify data into categories',
#  'opt2': 'To predict future values based on past data',
#  'opt3': 'To generate new data instances that resemble the training data',
#  'opt4': 'To identify patterns in unstructured data'}

# %%
answers[0]
# Out:
# {'question': 'What is the primary goal of generative modeling?',
#  'answer': 'To generate new data instances that resemble the training data',
#  'explanation': 'Generative models aim to learn the underlying data distribution to create new, similar data points.'}

# %%
mcq[1]
# Out:
# {'question': 'What are the two main components of a Generative Adversarial Network (GAN)?',
#  'opt1': 'Encoder and Decoder',
#  'opt2': 'Generator and Classifier',
#  'opt3': 'Generator and Discriminator',
#  'opt4': 'Discriminator and Classifier'}

# %%
answers[1]
# Out:
# {'question': 'What are the two main components of a Generative Adversarial Network (GAN)?',
#  'answer': 'Generator and Discriminator',
#  'explanation': 'GANs consist of a Generator, which creates new data, and a Discriminator, which evaluates the realism of the generated data.'}

# %%
mcq[2]
# Out:
# {'question': 'What is the role of the Generator in a GAN?',
#  'opt1': 'To classify data as real or fake',
#  'opt2': 'To generate new data instances',
#  'opt3': 'To evaluate the quality of generated data',
#  'opt4': 'To preprocess input data'}

# %%
answers[2]
# Out:
# {'question': 'What is the role of the Generator in a GAN?',
#  'answer': 'To generate new data instances',
#  'explanation': "The Generator's primary function is to create new data instances that resemble the training data."}

# %%
mcq[3]
# Out:
# {'question': 'What is the role of the Discriminator in a GAN?',
#  'opt1': 'To generate new data instances',
#  'opt2': 'To evaluate the quality of generated data',
#  'opt3': 'To classify data as real or fake',
#  'opt4': 'To preprocess input data'}

# %%
answers[3]
# Out:
# {'question': 'What is the role of the Discriminator in a GAN?',
#  'answer': 'To classify data as real or fake',
#  'explanation': "The Discriminator's role is to distinguish between real data samples and those generated by the Generator."}

# %%
mcq[4]
# Out:
# {'question': 'What type of output does the Discriminator typically produce?',
#  'opt1': 'A high-dimensional vector',
#  'opt2': 'A low-dimensional vector',
#  'opt3': 'A scalar value',
#  'opt4': 'A probability distribution'}

# %%
answers[4]
# Out:
# {'question': 'What type of output does the Discriminator typically produce?',
#  'answer': 'A scalar value',
#  'explanation': 'The Discriminator usually outputs a scalar value representing a probability (often between 0 and 1) indicating the likelihood of the input being real.'}

# %%
mcq[5]
# Out:
# {'question': 'How does the Discriminator provide feedback to the Generator?',
#  'opt1': 'By providing the ground truth labels',
#  'opt2': 'By assigning a score indicating the realism of generated data',
#  'opt3': "By directly modifying the Generator's parameters",
#  'opt4': 'By calculating the loss function'}

# %%
answers[5]
# Out:
# {'question': 'How does the Discriminator provide feedback to the Generator?',
#  'answer': 'By assigning a score indicating the realism of generated data',
#  'explanation': 'The Discriminator provides feedback to the Generator by assigning scores to the generated data, indicating how realistic the data is.'}

# %%
mcq[6]
# Out:
# {'question': "What is the concept of 'adversarial' in the context of GANs?",
#  'opt1': 'The two networks (Generator and Discriminator) compete against each other',
#  'opt2': 'The model is trained on a dataset of adversarial examples',
#  'opt3': 'The model is designed to be robust against adversarial attacks',
#  'opt4': 'The model uses adversarial examples to improve its performance'}

# %%
answers[6]
# Out:
# {'question': "What is the concept of 'adversarial' in the context of GANs?",
#  'answer': 'The two networks (Generator and Discriminator) compete against each other',
#  'explanation': "The 'adversarial' nature of GANs refers to the competitive training process where the Generator and Discriminator work against each other, constantly improving."}

# %%
mcq[7]
# Out:
# {'question': 'What is the primary goal of training a GAN?',
#  'opt1': 'To optimize the parameters of the Discriminator',
#  'opt2': 'To maximize the accuracy of both the Generator and Discriminator',
#  'opt3': 'To find the optimal parameters of the Generator',
#  'opt4': 'To minimize the loss function'}

# %%
answers[7]
# Out:
# {'question': 'What is the primary goal of training a GAN?',
#  'answer': 'To find the optimal parameters of the Generator',
#  'explanation': 'The goal of GAN training is to find the optimal parameters for the Generator, enabling it to produce highly realistic data that can fool the Discriminator.'}

# %%
mcq[8]
# Out:
# {'question': "What is 'hallucination' in the context of generative models?",
#  'opt1': 'When the model generates nonsensical or grammatically incorrect outputs',
#  'opt2': 'When the model generates outputs that are factually incorrect',
#  'opt3': 'When the model fails to generate any output',
#  'opt4': 'All of the above'}

# %%
answers[8]
# Out:
# {'question': "What is 'hallucination' in the context of generative models?",
#  'answer': 'All of the above',
#  'explanation': 'Hallucination encompasses generating nonsensical, factually incorrect, or grammatically flawed outputs'}

# %%
mcq[9]
# Out:
# {'question': 'What is a common way to evaluate GAN performance?',
#  'opt1': 'By calculating the accuracy of the Discriminator',
#  'opt2': 'By comparing the generated data to the real data using metrics',
#  'opt3': 'By analyzing the loss function values',
#  'opt4': 'All of the above'}

# %%
answers[9]
# Out:
# {'question': 'What is a common way to evaluate GAN performance?',
#  'answer': 'All of the above',
#  'explanation': "GAN performance can be assessed by various metrics, focusing on the Discriminator's accuracy, comparison of generated and real data, and analysis of the loss function."}

# %%
mcq[10]
# Out:
# {'question': 'What is a primary application of GANs?',
#  'opt1': 'Image generation',
#  'opt2': 'Text generation',
#  'opt3': 'Video generation',
#  'opt4': 'All of the above'}

# %%
answers[10]
# Out:
# {'question': 'What is a primary application of GANs?',
#  'answer': 'All of the above',
#  'explanation': 'GANs have wide applications across various domains like image generation, text generation and video generation.'}

# %%
mcq[11]
# Out:
# {'question': 'What kind of data is often used to provide input noise for the generator in a GAN?',
#  'opt1': 'Real data samples',
#  'opt2': 'Random noise vectors',
#  'opt3': 'Labelled data',
#  'opt4': 'Pre-trained embeddings'}

# %%
answers[11]
# Out:
# {'question': 'What kind of data is often used to provide input noise for the generator in a GAN?',
#  'answer': 'Random noise vectors',
#  'explanation': 'The Generator uses random noise as input, combined with any other inputs to generate new data instances.'}

# %%
mcq[12]
# Out:
# {'question': 'What is a potential limitation of GANs?',
#  'opt1': 'The training process is computationally expensive',
#  'opt2': 'They are prone to mode collapse',
#  'opt3': 'They can be difficult to train and tune',
#  'opt4': 'All of the above'}

# %%
answers[12]
# Out:
# {'question': 'What is a potential limitation of GANs?',
#  'answer': 'All of the above',
#  'explanation': 'GAN training is computationally expensive, can suffer from mode collapse where the model generates only a limited range of outputs and is notoriously difficult to train and tune.'}
