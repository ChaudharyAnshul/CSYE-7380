# %%
import pandas as pd

# %%
chapter1 = [
{
"question": "What is the most uniformly fascinating game in the world?",
"answer": "The game of speculation is the most uniformly fascinating game in the world."
},
{
"question": "Who is this game not for?",
"answer": "It's not for the stupid, mentally lazy, emotionally unbalanced, or get-rich-quick adventurers."
},
{
"question": "What is the common question people ask Jesse Livermore?",
"answer": "How can I make some money in the market?"
},
{
"question": "Why is it difficult to answer the question about making quick money in the market?",
"answer": "It implies a lack of respect for the scientific study of investment and speculation, like asking a surgeon how to make quick money in surgery."
},
{
"question": "What is the purpose of this book?",
"answer": "To provide guidance and signposts for those willing to work and study to attain sensible results in stock market investment and speculation."
},
{
"question": "What is the most important factor in successful speculation?",
"answer": "The time element in trading is the most important factor in successful speculation."
},
{
"question": "What is the warning given to readers regarding honesty and sincerity?",
"answer": "The fruits of success will be in direct ratio to the honesty and sincerity of your own effort in keeping your own records, thinking, and reaching your own conclusions."
},
{
"question": "Can you delegate the task of keeping your records to someone else?",
"answer": "No, you cannot delegate the task of keeping your records to another; you must do it yourself to follow the formula in this book."
},
{
"question": "What is the main point about making money in the stock market?",
"answer": "To make money, you need to anticipate coming market movements and you can only light the way."
},
{
"question": "How should one approach speculation?",
"answer": "Speculation should be treated as a business, not a gamble."
},
{
"question": "What is the author's experience with market speculation?",
"answer": "The author has studied world and domestic economic conditions with fanatic intensity for 40 years."
},
{
"question": "What is the author's first experience with speculation?",
"answer": "The author’s first sensation in the market occurred when he was fifteen; he made a thousand dollars from stock market gleanings."
},
{
"question": "How does the author describe his world and his science?",
"answer": "His world has been the movement of prices and his science the correct anticipation of such movements."
},
{
"question": "Can you consistently make money trading every day or every week?",
"answer": "No, only the foolhardy will try it."
},
{
"question": "What is speculation?",
"answer": "Speculation is anticipating coming movements."
},
{
"question": "What is needed to anticipate market movements correctly?",
"answer": "A definite basis for that anticipation; for example, analyze the effect of news on the market."
},
{
"question": "What is crucial when making commitments in the market?",
"answer": "Patience and waiting to avoid being too anxious to get into a stock or stocks."
},
{
"question": "What is a good example illustrating the significance of patience in trading?",
"answer": "A stock selling around \\$25.00 and holding within a range of \\$22.00 to \\$28.00; assuming you believe it should sell at \\$50.00, you wait until the stock becomes active and makes a new high."
},
{
"question": "What should you do if a stock you own goes to \\$30.00 from \\$25.00?",
"answer": "You should know that marketwise you have been justified because the stock must have gone into a very strong position."
},
{
"question": "What should you do if the stock you own drops to \\$28.00 from \\$30.00?",
"answer": "You should be worried because that two-point loss could be followed by two more points the next day, or possibly five or ten within the next week."
},
{
"question": "What is the main point about profits and losses in speculation?",
"answer": "Profits always take care of themselves, but losses never do. The speculator has to insure himself against considerable losses by taking the first small loss."
},
{
"question": "How should speculators view speculation?",
"answer": "Speculators should treat speculation as a business; learn and understand it to the best of their ability."
},
{
"question": "What is the importance of having rules in speculation?",
"answer": "To be consistently successful, an investor or speculator must have rules to guide him."
},
{
"question": "What is the author's method of keeping records and how does it help him?",
"answer": "The author’s recording method gives him a clear picture of what is happening and helps him anticipate coming movements."
},
{
"question": "What is the author's theory about time element in trading?",
"answer": "The author's theory is that the time element in trading is the most important factor in successful speculation."
},
{
"question": "What is the warning given about being too anxious to get into the market?",
"answer": "Don't be too anxious to get into a stock or stocks; wait and watch the action of that stock or stocks marketwise."
},
{
"question": "What is the author's advice to those who wish to make quick and easy money in speculation?",
"answer": "The author advises against this; the fruits of your success will be in direct ratio to your own effort."
},
{
"question": "What is the author’s opinion on the importance of maintaining records?",
"answer": "Maintaining records is crucial for understanding market movements. Analyzing records helps to identify patterns and predict future movements."
},
{
"question": "What is the author's opinion about patience in trading?",
"answer": "Patience is crucial in trading; rushing into trades often leads to losses. A well-defined strategy and careful analysis are more effective."
},
{
"question": "What is the author’s experience with discovering new rules in the business of speculation?",
"answer": "The author has been discovering new rules for forty years and that the lessons learned from each failure and success are crucial."
},
{
"question": "What's the author's view on the importance of combining time element and prices?",
"answer": "Combining the time element and prices is crucial for successful speculation."
},
{
"question": "What's the author’s advice about following your own conclusions?",
"answer": "You must reach your own conclusions to wisely read a book on how to keep fit and cannot delegate the task of keeping your records to another."
},
{
"question": "What's the author’s opinion regarding the use of charts or records?",
"answer": "The author prefers records over charts because charts can be confusing.  Records provide a clearer picture of what's happening."
},
{
"question": "What's the author’s view on the role of human emotions in speculation?",
"answer": "Human emotions, such as impatience and fear, can negatively affect trading decisions. It is important to remain rational and controlled."
},
{
"question": "What's the author’s advice on the importance of studying market conditions?",
"answer": "Studying market conditions is essential to successful speculation; the market itself acts as a guide."
},
{
"question": "What's the author’s opinion on the importance of having a clear understanding of your own trading style?",
"answer": "Understanding your own trading style is crucial for success; it informs decisions and enables you to adapt to market conditions."
},
{
"question": "What's the author's final thought on the challenge of speculation?",
"answer": "The game of speculation is not for everyone; success requires patience, discipline, and a systematic approach."
}
]

# %%
df_1 = pd.DataFrame(chapter1)
df_1
# Out:
#                                              question  \
# 0   What is the most uniformly fascinating game in...
# 1                           Who is this game not for?
# 2   What is the common question people ask Jesse L...
# 3   Why is it difficult to answer the question abo...
# 4                   What is the purpose of this book?
# 5   What is the most important factor in successfu...
# 6   What is the warning given to readers regarding...
# 7   Can you delegate the task of keeping your reco...
# 8   What is the main point about making money in t...
# 9                How should one approach speculation?
# 10  What is the author's experience with market sp...
# 11  What is the author's first experience with spe...
# 12  How does the author describe his world and his...
# 13  Can you consistently make money trading every ...
# 14                               What is speculation?
# 15  What is needed to anticipate market movements ...
# ...
