# %% [markdown]
# - 2 layers
# - sigmoid(LSTM) and linear(density) as activation function
# - 50 neurons
# - 50 epoch
# - 30 batch size

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import warnings
warnings.filterwarnings('ignore')

from pathlib import Path
import numpy as np
import pandas as pd
import pandas_datareader.data as web
from scipy.stats import spearmanr

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
import yfinance as yf

# %%
# Set up the random state
sns.set_style('whitegrid')
np.random.seed(42)

# %%
start_date = datetime(2020,1,1)
end_date = datetime(2024,8,31)
stock_symbol = 'NVDA'

# %%
stocks = yf.download(stock_symbol, start_date, end_date)
price_type = 'Adj Close'
stock_price = pd.DataFrame(stocks[price_type])
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ax = stock_price.plot(title = stock_symbol, legend=False, linewidth = 2, figsize=(14, 4), rot=0)
ax.set_xlabel('')
sns.despine()

# %%
scaler = MinMaxScaler()
stocks_scaled = pd.Series(scaler.fit_transform(stock_price.values.reshape(-1, 1)).squeeze(), index=stock_price.index)

# %%
def create_univariate_lstm_data(data, window_size):
    n = len(data)
    y = data[window_size:]
    data = data.values.reshape(-1, 1)  # make 2D
    X = np.hstack(tuple([data[i: n-j, :] for i, j in enumerate(range(window_size, 0, -1))]))
    return pd.DataFrame(X, index=y.index), y

window_size = 60
X, y = create_univariate_lstm_data(stocks_scaled, window_size=window_size)

# %%
X_train = X[:'2022'].values.reshape(-1, window_size, 1)
y_train = y[:'2022']
X_test = X['2023':].values.reshape(-1, window_size, 1)
y_test = y['2023':]

# %%
def create_LSTM(hidden_units, dense_units, input_shape, activation):
    model = Sequential()
    model.add(LSTM(hidden_units, input_shape=input_shape, return_sequences=False, activation=activation[3]))
    model.add(Dense(units=dense_units, activation=activation[0]))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
lstm = create_LSTM(hidden_units=50, dense_units=1, input_shape=(window_size, 1), activation=['linear', 'relu', 'tanh', 'sigmoid'])
lstm.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 50)             │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,451 (40.82 KB)
#  Trainable params: 10,451 (40.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
LSTM_training = lstm.fit(X_train, 
                        y_train, 
                        epochs=50, 
                        batch_size=30, 
                        validation_data=(X_test, y_test), 
                        verbose=1
                    )
# Out:
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0037 - val_loss: 0.1520
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022 - val_loss: 0.1418
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0019 - val_loss: 0.1389
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0016 - val_loss: 0.1258
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.1155
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0013 - val_loss: 0.0948
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0011 - val_loss: 0.0826
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0011 - val_loss: 0.0654
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0010 - val_loss: 0.0612
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.0082e-04 - val_loss: 0.0524
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.2014e-04 - val_loss: 0.0467
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.9567e-04 - val_loss: 0.0378
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.1882e-04 - val_loss: 0.0340
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.2005e-04 - val_loss: 0.0241
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1922e-04 - val_loss: 0.0210
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.6357e-04 - val_loss: 0.0171
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9523e-04 - val_loss: 0.0132
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.5407e-04 - val_loss: 0.0093
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2568e-04 - val_loss: 0.0082
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1015e-04 - val_loss: 0.0063
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1016e-04 - val_loss: 0.0047
# Epoch 22/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.0557e-05 - val_loss: 0.0033
# Epoch 23/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.0615e-05 - val_loss: 0.0026
# Epoch 24/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.1831e-05 - val_loss: 0.0020
# Epoch 25/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.4609e-05 - val_loss: 0.0018
# Epoch 26/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.5182e-05 - val_loss: 0.0013
# Epoch 27/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.4703e-05 - val_loss: 0.0010
# Epoch 28/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.3400e-05 - val_loss: 8.4728e-04
# Epoch 29/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9066e-05 - val_loss: 9.4165e-04
# Epoch 30/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7777e-05 - val_loss: 6.8497e-04
# Epoch 31/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.8410e-05 - val_loss: 6.7551e-04
# Epoch 32/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.4958e-05 - val_loss: 6.4958e-04
# Epoch 33/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.3295e-05 - val_loss: 7.5078e-04
# Epoch 34/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7201e-05 - val_loss: 5.1603e-04
# Epoch 35/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.1991e-05 - val_loss: 4.8800e-04
# Epoch 36/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.4266e-05 - val_loss: 6.0237e-04
# Epoch 37/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.2643e-05 - val_loss: 6.2979e-04
# Epoch 38/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.6249e-05 - val_loss: 4.9370e-04
# Epoch 39/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.3774e-05 - val_loss: 4.9494e-04
# Epoch 40/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.2031e-05 - val_loss: 7.5556e-04
# Epoch 41/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.3577e-05 - val_loss: 6.9453e-04
# Epoch 42/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.2452e-05 - val_loss: 6.1455e-04
# Epoch 43/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.9880e-05 - val_loss: 6.2502e-04
# Epoch 44/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.6965e-05 - val_loss: 4.7133e-04
# Epoch 45/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.3751e-05 - val_loss: 5.2657e-04
# Epoch 46/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.4042e-05 - val_loss: 5.4557e-04
# Epoch 47/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.1092e-05 - val_loss: 5.4690e-04
# Epoch 48/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.4988e-05 - val_loss: 9.2034e-04
# Epoch 49/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0247e-04 - val_loss: 6.3752e-04
# Epoch 50/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1880e-05 - val_loss: 4.7100e-04

# %%
fig, ax = plt.subplots(figsize=(12, 4))

loss_history = pd.DataFrame(LSTM_training.history).pow(.5)
loss_history.index += 1
best_rmse = loss_history.val_loss.min()

best_epoch = loss_history.val_loss.idxmin()

title = f'5-Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
loss_history.columns=['Training RMSE', 'Validation RMSE']
loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=ax)

ax.axvline(best_epoch, ls='--', lw=1, c='k')

sns.despine()
fig.tight_layout()

# %%
train_rmse_scaled = np.sqrt(lstm.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(lstm.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE (scaled): {train_rmse_scaled:.4f} | Test RMSE (scaled): {test_rmse_scaled:.4f}')
# Out:
# Train RMSE (scaled): 0.0117 | Test RMSE (scaled): 0.0217

# %%
train_predict_scaled = lstm.predict(X_train)
test_predict_scaled = lstm.predict(X_test)

train_ic = spearmanr(y_train, train_predict_scaled)[0]
test_ic = spearmanr(y_test, test_predict_scaled)[0]
print(f"Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Train IC: 0.9901 | Test IC: 0.9936

# %%
train_predict = pd.Series(scaler.inverse_transform(train_predict_scaled).squeeze(), index=y_train.index)
test_predict = (pd.Series(scaler.inverse_transform(test_predict_scaled).squeeze(), index=y_test.index))
# use inverse_transform to convert the scaled data back to its original scale.
y_train_rescaled = scaler.inverse_transform(y_train.to_frame()).squeeze()
y_test_rescaled = scaler.inverse_transform(y_test.to_frame()).squeeze()

# %%
train_rmse = np.sqrt(mean_squared_error(train_predict, y_train_rescaled))
test_rmse = np.sqrt(mean_squared_error(test_predict, y_test_rescaled))
print(f"Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}")
# Out:
# Train RMSE: 1.53 | Test RMSE: 2.84

# %%
stock_price['Train Predictions'] = train_predict
stock_price['Test Predictions'] = test_predict

to_be_merged = pd.concat([train_predict.to_frame('predictions').assign(data='Train'),
                   test_predict.to_frame('predictions').assign(data='Test')])

stock_price = pd.merge(stock_price, to_be_merged, how='inner', on='Date')
stock_price.columns = stock_price.columns.str.rstrip('_x').str.rstrip('_y')

# %%
stock_price
# Out:
#              Adj Close  Train Predictions  Test Predictions  predictions  \
# Date
# 2020-03-30    6.616441           7.687542               NaN     7.687542
# 2020-03-31    6.566866           7.907435               NaN     7.907435
# 2020-04-01    6.055417           7.942650               NaN     7.942650
# 2020-04-02    6.364330           7.681049               NaN     7.681049
# 2020-04-03    6.076344           7.831355               NaN     7.831355
# ...                ...                ...               ...          ...
# 2024-08-26  126.449181                NaN        125.147545   125.147545
# 2024-08-27  128.289032                NaN        124.119576   124.119576
# 2024-08-28  125.599258                NaN        125.263275   125.263275
# 2024-08-29  117.579941                NaN        124.045242   124.045242
# 2024-08-30  119.359795                NaN        119.406914   119.406914
#
#              data
# Date
# 2020-03-30  Train
# 2020-03-31  Train
# 2020-04-01  Train
# 2020-04-02  Train
# 2020-04-03  Train
# ...           ...
# 2024-08-26   Test
# 2024-08-27   Test
# 2024-08-28   Test
# 2024-08-29   Test
# 2024-08-30   Test
#
# [1114 rows x 5 columns]

# %%
fig=plt.figure(figsize=(14,7))
ax1 = plt.subplot(221)
stock_price.loc['2020':, price_type].plot(lw=2, ax=ax1, c='k')
stock_price.loc['2020':, ['Test Predictions', 'Train Predictions']].plot(lw=1, ax=ax1, ls='--')
ax1.set_title('In- and Out-of-sample Predictions')

with sns.axes_style("white"):
    ax3 = plt.subplot(223)
    sns.scatterplot(x = price_type, y = 'predictions', data = stock_price, hue = 'data', ax = ax3)
    ax3.text(x=.02, y=.95, s=f'Test IC ={test_ic:.2%}', transform=ax3.transAxes)
    ax3.text(x=.02, y=.87, s=f'Train IC={train_ic:.2%}', transform=ax3.transAxes)
    ax3.set_title('Correlation')
    ax3.legend(loc='lower right')

    ax2 = plt.subplot(222)
    ax4 = plt.subplot(224, sharex = ax2, sharey=ax2)
    sns.distplot(train_predict.squeeze()- y_train_rescaled, ax=ax2)
    ax2.set_title('Train Error')
    ax2.text(x=.03, y=.92, s=f'Train RMSE = ${train_rmse:.4f}', transform=ax2.transAxes)
    sns.distplot(test_predict.squeeze()-y_test_rescaled, ax=ax4)
    ax4.set_title('Test Error')
    ax4.text(x=.03, y=.92, s=f'Test RMSE = ${test_rmse:.4f}', transform=ax4.transAxes)

sns.despine()
fig.tight_layout()
