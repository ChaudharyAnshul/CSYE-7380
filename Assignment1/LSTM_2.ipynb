# %% [markdown]
# - 2 layers
# - sigmoid(LSTM) and linear(density) as activation function
# - 100 neurons
# - 80 epoch
# - 30 batch size

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import warnings
warnings.filterwarnings('ignore')

from pathlib import Path
import numpy as np
import pandas as pd
import pandas_datareader.data as web
from scipy.stats import spearmanr

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
import yfinance as yf

# %%
# Set up the random state
sns.set_style('whitegrid')
np.random.seed(42)

# %%
start_date = datetime(2020,1,1)
end_date = datetime(2024,8,31)
stock_symbol = 'NVDA'

# %%
stocks = yf.download(stock_symbol, start_date, end_date)
price_type = 'Adj Close'
stock_price = pd.DataFrame(stocks[price_type])
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ax = stock_price.plot(title = stock_symbol, legend=False, linewidth = 2, figsize=(14, 4), rot=0)
ax.set_xlabel('')
sns.despine()

# %%
scaler = MinMaxScaler()
stocks_scaled = pd.Series(scaler.fit_transform(stock_price.values.reshape(-1, 1)).squeeze(), index=stock_price.index)

# %%
def create_univariate_lstm_data(data, window_size):
    n = len(data)
    y = data[window_size:]
    data = data.values.reshape(-1, 1)  # make 2D
    X = np.hstack(tuple([data[i: n-j, :] for i, j in enumerate(range(window_size, 0, -1))]))
    return pd.DataFrame(X, index=y.index), y

window_size = 60
X, y = create_univariate_lstm_data(stocks_scaled, window_size=window_size)

# %%
X_train = X[:'2022'].values.reshape(-1, window_size, 1)
y_train = y[:'2022']
X_test = X['2023':].values.reshape(-1, window_size, 1)
y_test = y['2023':]

# %%
def create_LSTM(hidden_units, dense_units, input_shape, activation):
    model = Sequential()
    model.add(LSTM(hidden_units, input_shape=input_shape, return_sequences=False, activation=activation[3]))
    model.add(Dense(units=dense_units, activation=activation[0]))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
lstm = create_LSTM(hidden_units=100, dense_units=1, input_shape=(window_size, 1), activation=['linear', 'relu', 'tanh', 'sigmoid'])
lstm.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 100)            │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,901 (159.77 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
LSTM_training = lstm.fit(X_train, 
                        y_train, 
                        epochs=80, 
                        batch_size=30, 
                        validation_data=(X_test, y_test), 
                        verbose=1
                    )
# Out:
# Epoch 1/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0065 - val_loss: 0.1620
# Epoch 2/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0020 - val_loss: 0.1566
# Epoch 3/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0019 - val_loss: 0.1441
# Epoch 4/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0018 - val_loss: 0.1303
# Epoch 5/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0015 - val_loss: 0.1084
# Epoch 6/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0013 - val_loss: 0.0937
# Epoch 7/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0011 - val_loss: 0.0820
# Epoch 8/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 9.9050e-04 - val_loss: 0.0647
# Epoch 9/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.7711e-04 - val_loss: 0.0680
# Epoch 10/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.5740e-04 - val_loss: 0.0495
# Epoch 11/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.6609e-04 - val_loss: 0.0381
# Epoch 12/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.5125e-04 - val_loss: 0.0302
# Epoch 13/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.7589e-04 - val_loss: 0.0311
# Epoch 14/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.6551e-04 - val_loss: 0.0226
# Epoch 15/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.8586e-04 - val_loss: 0.0184
# Epoch 16/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.3855e-04 - val_loss: 0.0153
# Epoch 17/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.7032e-04 - val_loss: 0.0126
# Epoch 18/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.0372e-04 - val_loss: 0.0067
# Epoch 19/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.7565e-04 - val_loss: 0.0077
# Epoch 20/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.6394e-05 - val_loss: 0.0059
# Epoch 21/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.1172e-04 - val_loss: 0.0036
# Epoch 22/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.7189e-05 - val_loss: 0.0023
# Epoch 23/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.4344e-05 - val_loss: 0.0022
# Epoch 24/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.7262e-05 - val_loss: 0.0017
# Epoch 25/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.9360e-05 - val_loss: 0.0015
# Epoch 26/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.3969e-05 - val_loss: 0.0011
# Epoch 27/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.3940e-05 - val_loss: 0.0011
# Epoch 28/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.2257e-05 - val_loss: 7.0989e-04
# Epoch 29/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.2955e-05 - val_loss: 5.5332e-04
# Epoch 30/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.2570e-05 - val_loss: 6.3228e-04
# Epoch 31/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.5343e-05 - val_loss: 4.7809e-04
# Epoch 32/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.1181e-04 - val_loss: 5.7046e-04
# Epoch 33/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.9806e-05 - val_loss: 7.7251e-04
# Epoch 34/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.1660e-05 - val_loss: 4.7821e-04
# Epoch 35/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.3682e-05 - val_loss: 5.6608e-04
# Epoch 36/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.8783e-05 - val_loss: 8.1378e-04
# Epoch 37/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.3478e-05 - val_loss: 5.0413e-04
# Epoch 38/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.6171e-05 - val_loss: 4.6616e-04
# Epoch 39/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.5016e-05 - val_loss: 4.7327e-04
# Epoch 40/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.5292e-05 - val_loss: 7.7926e-04
# Epoch 41/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.6168e-05 - val_loss: 6.1247e-04
# Epoch 42/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.5091e-05 - val_loss: 5.4494e-04
# Epoch 43/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.4964e-05 - val_loss: 6.2276e-04
# Epoch 44/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.6031e-05 - val_loss: 5.8783e-04
# Epoch 45/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.7888e-05 - val_loss: 0.0012
# Epoch 46/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.6054e-04 - val_loss: 4.5474e-04
# Epoch 47/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.7345e-04 - val_loss: 6.1977e-04
# Epoch 48/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.8368e-05 - val_loss: 5.3410e-04
# Epoch 49/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.8779e-05 - val_loss: 7.8534e-04
# Epoch 50/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.2284e-05 - val_loss: 6.1298e-04
# Epoch 51/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.5215e-05 - val_loss: 5.7506e-04
# Epoch 52/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.3946e-05 - val_loss: 9.7833e-04
# Epoch 53/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.1509e-04 - val_loss: 6.3008e-04
# Epoch 54/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.4732e-05 - val_loss: 4.3225e-04
# Epoch 55/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0607e-04 - val_loss: 6.7141e-04
# Epoch 56/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.3891e-05 - val_loss: 4.6100e-04
# Epoch 57/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.7043e-05 - val_loss: 8.5494e-04
# Epoch 58/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0663e-04 - val_loss: 5.6007e-04
# Epoch 59/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.2514e-05 - val_loss: 6.3156e-04
# Epoch 60/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.7104e-05 - val_loss: 4.7198e-04
# Epoch 61/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.3140e-05 - val_loss: 4.2962e-04
# Epoch 62/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.8287e-05 - val_loss: 6.0424e-04
# Epoch 63/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.7240e-05 - val_loss: 4.4225e-04
# Epoch 64/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.0739e-04 - val_loss: 5.9790e-04
# Epoch 65/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.6556e-05 - val_loss: 4.8292e-04
# Epoch 66/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.4193e-05 - val_loss: 4.4652e-04
# Epoch 67/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 9.7579e-05 - val_loss: 6.0014e-04
# Epoch 68/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.3781e-05 - val_loss: 4.5378e-04
# Epoch 69/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.0519e-05 - val_loss: 6.0666e-04
# Epoch 70/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.0029e-04 - val_loss: 8.7906e-04
# Epoch 71/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.3542e-05 - val_loss: 5.0240e-04
# Epoch 72/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.4061e-05 - val_loss: 8.7252e-04
# Epoch 73/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.2241e-05 - val_loss: 6.5339e-04
# Epoch 74/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.9319e-05 - val_loss: 4.2188e-04
# Epoch 75/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.2250e-04 - val_loss: 8.3193e-04
# Epoch 76/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.3939e-05 - val_loss: 4.5048e-04
# Epoch 77/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.0846e-05 - val_loss: 6.0759e-04
# Epoch 78/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.7551e-05 - val_loss: 4.4456e-04
# Epoch 79/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.6306e-05 - val_loss: 4.8050e-04
# Epoch 80/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.4446e-05 - val_loss: 7.8350e-04

# %%
fig, ax = plt.subplots(figsize=(12, 4))

loss_history = pd.DataFrame(LSTM_training.history).pow(.5)
loss_history.index += 1
best_rmse = loss_history.val_loss.min()

best_epoch = loss_history.val_loss.idxmin()

title = f'5-Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
loss_history.columns=['Training RMSE', 'Validation RMSE']
loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=ax)

ax.axvline(best_epoch, ls='--', lw=1, c='k')

sns.despine()
fig.tight_layout()

# %%
train_rmse_scaled = np.sqrt(lstm.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(lstm.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE (scaled): {train_rmse_scaled:.4f} | Test RMSE (scaled): {test_rmse_scaled:.4f}')
# Out:
# Train RMSE (scaled): 0.0118 | Test RMSE (scaled): 0.0280

# %%
train_predict_scaled = lstm.predict(X_train)
test_predict_scaled = lstm.predict(X_test)

train_ic = spearmanr(y_train, train_predict_scaled)[0]
test_ic = spearmanr(y_test, test_predict_scaled)[0]
print(f"Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Train IC: 0.9909 | Test IC: 0.9941

# %%
train_predict = pd.Series(scaler.inverse_transform(train_predict_scaled).squeeze(), index=y_train.index)
test_predict = (pd.Series(scaler.inverse_transform(test_predict_scaled).squeeze(), index=y_test.index))
# use inverse_transform to convert the scaled data back to its original scale.
y_train_rescaled = scaler.inverse_transform(y_train.to_frame()).squeeze()
y_test_rescaled = scaler.inverse_transform(y_test.to_frame()).squeeze()

# %%
train_rmse = np.sqrt(mean_squared_error(train_predict, y_train_rescaled))
test_rmse = np.sqrt(mean_squared_error(test_predict, y_test_rescaled))
print(f"Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}")
# Out:
# Train RMSE: 1.54 | Test RMSE: 3.66

# %%
stock_price['Train Predictions'] = train_predict
stock_price['Test Predictions'] = test_predict

to_be_merged = pd.concat([train_predict.to_frame('predictions').assign(data='Train'),
                   test_predict.to_frame('predictions').assign(data='Test')])

stock_price = pd.merge(stock_price, to_be_merged, how='inner', on='Date')
stock_price.columns = stock_price.columns.str.rstrip('_x').str.rstrip('_y')

# %%
stock_price
# Out:
#              Adj Close  Train Predictions  Test Predictions  predictions  \
# Date
# 2020-03-30    6.616442           4.917943               NaN     4.917943
# 2020-03-31    6.566866           5.157372               NaN     5.157372
# 2020-04-01    6.055418           5.181407               NaN     5.181407
# 2020-04-02    6.364329           4.883157               NaN     4.883157
# 2020-04-03    6.076344           5.057936               NaN     5.057936
# ...                ...                ...               ...          ...
# 2024-08-26  126.449181                NaN        124.093056   124.093056
# 2024-08-27  128.289032                NaN        122.767578   122.767578
# 2024-08-28  125.599258                NaN        124.009674   124.009674
# 2024-08-29  117.579941                NaN        122.544907   122.544907
# 2024-08-30  119.359795                NaN        117.332001   117.332001
#
#              data
# Date
# 2020-03-30  Train
# 2020-03-31  Train
# 2020-04-01  Train
# 2020-04-02  Train
# 2020-04-03  Train
# ...           ...
# 2024-08-26   Test
# 2024-08-27   Test
# 2024-08-28   Test
# 2024-08-29   Test
# 2024-08-30   Test
#
# [1114 rows x 5 columns]

# %%
fig=plt.figure(figsize=(14,7))
ax1 = plt.subplot(221)
stock_price.loc['2020':, price_type].plot(lw=2, ax=ax1, c='k')
stock_price.loc['2020':, ['Test Predictions', 'Train Predictions']].plot(lw=1, ax=ax1, ls='--')
ax1.set_title('In- and Out-of-sample Predictions')

with sns.axes_style("white"):
    ax3 = plt.subplot(223)
    sns.scatterplot(x = price_type, y = 'predictions', data = stock_price, hue = 'data', ax = ax3)
    ax3.text(x=.02, y=.95, s=f'Test IC ={test_ic:.2%}', transform=ax3.transAxes)
    ax3.text(x=.02, y=.87, s=f'Train IC={train_ic:.2%}', transform=ax3.transAxes)
    ax3.set_title('Correlation')
    ax3.legend(loc='lower right')

    ax2 = plt.subplot(222)
    ax4 = plt.subplot(224, sharex = ax2, sharey=ax2)
    sns.distplot(train_predict.squeeze()- y_train_rescaled, ax=ax2)
    ax2.set_title('Train Error')
    ax2.text(x=.03, y=.92, s=f'Train RMSE = ${train_rmse:.4f}', transform=ax2.transAxes)
    sns.distplot(test_predict.squeeze()-y_test_rescaled, ax=ax4)
    ax4.set_title('Test Error')
    ax4.text(x=.03, y=.92, s=f'Test RMSE = ${test_rmse:.4f}', transform=ax4.transAxes)

sns.despine()
fig.tight_layout()
