# %% [markdown]
# - 2 layers
# - relu(LSTM) and linear(density) as activation function
# - 100 neurons
# - 80 epoch
# - 30 batch size

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import warnings
warnings.filterwarnings('ignore')

from pathlib import Path
import numpy as np
import pandas as pd
import pandas_datareader.data as web
from scipy.stats import spearmanr

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
import yfinance as yf
# Out:
# 2024-10-09 18:43:32.642353: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-09 18:43:32.645435: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-09 18:43:32.655943: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-09 18:43:32.674076: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-09 18:43:32.679028: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-09 18:43:32.693020: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-09 18:43:33.684798: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Set up the random state
sns.set_style('whitegrid')
np.random.seed(42)

# %%
start_date = datetime(2020,1,1)
end_date = datetime(2024,8,31)
stock_symbol = 'NVDA'

# %%
stocks = yf.download(stock_symbol, start_date, end_date)
price_type = 'Adj Close'
stock_price = pd.DataFrame(stocks[price_type])
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ax = stock_price.plot(title = stock_symbol, legend=False, linewidth = 2, figsize=(14, 4), rot=0)
ax.set_xlabel('')
sns.despine()

# %%
scaler = MinMaxScaler()
stocks_scaled = pd.Series(scaler.fit_transform(stock_price.values.reshape(-1, 1)).squeeze(), index=stock_price.index)

# %%
def create_univariate_lstm_data(data, window_size):
    n = len(data)
    y = data[window_size:]
    data = data.values.reshape(-1, 1)  # make 2D
    X = np.hstack(tuple([data[i: n-j, :] for i, j in enumerate(range(window_size, 0, -1))]))
    return pd.DataFrame(X, index=y.index), y

window_size = 60
X, y = create_univariate_lstm_data(stocks_scaled, window_size=window_size)

# %%
X_train = X[:'2022'].values.reshape(-1, window_size, 1)
y_train = y[:'2022']
X_test = X['2023':].values.reshape(-1, window_size, 1)
y_test = y['2023':]

# %%
def create_LSTM(hidden_units, dense_units, input_shape, activation):
    model = Sequential()
    model.add(LSTM(hidden_units, input_shape=input_shape, return_sequences=False, activation=activation[1]))
    model.add(Dense(units=dense_units, activation=activation[0]))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
lstm = create_LSTM(hidden_units=100, dense_units=1, input_shape=(window_size, 1), activation=['linear', 'relu'])
lstm.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728513815.496755   75834 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-09 18:43:35.497302: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2343] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100)            │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,901 (159.77 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
LSTM_training = lstm.fit(X_train, 
                        y_train, 
                        epochs=80, 
                        batch_size=30, 
                        validation_data=(X_test, y_test), 
                        verbose=1
                    )
# Out:
# Epoch 1/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0033 - val_loss: 0.0459
# Epoch 2/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.3134e-04 - val_loss: 0.0045
# Epoch 3/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.0895e-04 - val_loss: 0.0118
# Epoch 4/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.4344e-05 - val_loss: 0.0372
# Epoch 5/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.4524e-05 - val_loss: 0.0175
# Epoch 6/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.8191e-05 - val_loss: 0.0090
# Epoch 7/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 9.0131e-05 - val_loss: 0.0191
# Epoch 8/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.6942e-05 - val_loss: 0.0095
# Epoch 9/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 7.9313e-05 - val_loss: 0.0055
# Epoch 10/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.0088e-05 - val_loss: 0.0084
# Epoch 11/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.3780e-05 - val_loss: 0.0031
# Epoch 12/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.7536e-05 - val_loss: 0.0057
# Epoch 13/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.3998e-05 - val_loss: 0.0033
# Epoch 14/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.5984e-05 - val_loss: 0.0021
# Epoch 15/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.1048e-05 - val_loss: 0.0023
# Epoch 16/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.2373e-05 - val_loss: 0.0016
# Epoch 17/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.3071e-05 - val_loss: 0.0020
# Epoch 18/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.9075e-05 - val_loss: 0.0013
# Epoch 19/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.8935e-05 - val_loss: 0.0017
# Epoch 20/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.3127e-05 - val_loss: 0.0011
# Epoch 21/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.3416e-05 - val_loss: 0.0013
# Epoch 22/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 9.5425e-05 - val_loss: 0.0012
# Epoch 23/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.9194e-05 - val_loss: 0.0010
# Epoch 24/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.3884e-05 - val_loss: 0.0010
# Epoch 25/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.2170e-05 - val_loss: 0.0010
# Epoch 26/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.1287e-05 - val_loss: 0.0012
# Epoch 27/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.0183e-05 - val_loss: 9.1181e-04
# Epoch 28/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.8761e-05 - val_loss: 8.9581e-04
# Epoch 29/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.7816e-05 - val_loss: 0.0013
# Epoch 30/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.0302e-05 - val_loss: 0.0010
# Epoch 31/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.8920e-05 - val_loss: 9.9081e-04
# Epoch 32/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.6591e-05 - val_loss: 8.6181e-04
# Epoch 33/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.1609e-05 - val_loss: 0.0012
# Epoch 34/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.4357e-05 - val_loss: 9.7001e-04
# Epoch 35/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.5634e-05 - val_loss: 0.0010
# Epoch 36/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.3228e-05 - val_loss: 0.0012
# Epoch 37/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.4231e-05 - val_loss: 7.5667e-04
# Epoch 38/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.6736e-05 - val_loss: 8.5174e-04
# Epoch 39/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.7839e-05 - val_loss: 9.9096e-04
# Epoch 40/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.6352e-05 - val_loss: 7.5513e-04
# Epoch 41/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.0079e-05 - val_loss: 0.0014
# Epoch 42/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.3971e-05 - val_loss: 7.1760e-04
# Epoch 43/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.0802e-05 - val_loss: 9.5755e-04
# Epoch 44/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.1952e-05 - val_loss: 8.2794e-04
# Epoch 45/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.5230e-05 - val_loss: 7.4824e-04
# Epoch 46/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.7194e-05 - val_loss: 0.0012
# Epoch 47/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.2459e-05 - val_loss: 7.0662e-04
# Epoch 48/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.1704e-05 - val_loss: 0.0015
# Epoch 49/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.3820e-05 - val_loss: 9.7603e-04
# Epoch 50/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.5349e-05 - val_loss: 8.4866e-04
# Epoch 51/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.3578e-05 - val_loss: 8.1153e-04
# Epoch 52/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.7302e-05 - val_loss: 6.8645e-04
# Epoch 53/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.6314e-05 - val_loss: 0.0011
# Epoch 54/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.9247e-05 - val_loss: 6.4037e-04
# Epoch 55/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.1951e-05 - val_loss: 9.9396e-04
# Epoch 56/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.6526e-05 - val_loss: 8.2065e-04
# Epoch 57/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.9577e-05 - val_loss: 7.5310e-04
# Epoch 58/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.8123e-05 - val_loss: 7.8465e-04
# Epoch 59/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.6548e-05 - val_loss: 9.8536e-04
# Epoch 60/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.7401e-05 - val_loss: 8.5396e-04
# Epoch 61/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.2600e-05 - val_loss: 8.3623e-04
# Epoch 62/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.1894e-05 - val_loss: 6.4101e-04
# Epoch 63/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.0432e-05 - val_loss: 7.5686e-04
# Epoch 64/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.0675e-05 - val_loss: 7.4810e-04
# Epoch 65/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.2802e-05 - val_loss: 0.0011
# Epoch 66/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.2087e-05 - val_loss: 8.5677e-04
# Epoch 67/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.3032e-05 - val_loss: 6.8629e-04
# Epoch 68/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.7501e-05 - val_loss: 0.0010
# Epoch 69/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.5415e-05 - val_loss: 8.5211e-04
# Epoch 70/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.2487e-05 - val_loss: 6.0611e-04
# Epoch 71/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.6641e-05 - val_loss: 8.4818e-04
# Epoch 72/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.5558e-05 - val_loss: 5.9009e-04
# Epoch 73/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.1167e-05 - val_loss: 8.9850e-04
# Epoch 74/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.4736e-05 - val_loss: 6.1500e-04
# Epoch 75/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.6418e-05 - val_loss: 7.5517e-04
# Epoch 76/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.7036e-05 - val_loss: 8.1517e-04
# Epoch 77/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.3885e-05 - val_loss: 6.1106e-04
# Epoch 78/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.9738e-05 - val_loss: 7.7860e-04
# Epoch 79/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.2635e-05 - val_loss: 5.8169e-04
# Epoch 80/80
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.2977e-05 - val_loss: 6.4082e-04

# %%
fig, ax = plt.subplots(figsize=(12, 4))

loss_history = pd.DataFrame(LSTM_training.history).pow(.5)
loss_history.index += 1
best_rmse = loss_history.val_loss.min()

best_epoch = loss_history.val_loss.idxmin()

title = f'5-Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
loss_history.columns=['Training RMSE', 'Validation RMSE']
loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=ax)

ax.axvline(best_epoch, ls='--', lw=1, c='k')

sns.despine()
fig.tight_layout()

# %%
train_rmse_scaled = np.sqrt(lstm.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(lstm.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE (scaled): {train_rmse_scaled:.4f} | Test RMSE (scaled): {test_rmse_scaled:.4f}')
# Out:
# Train RMSE (scaled): 0.0057 | Test RMSE (scaled): 0.0253

# %%
train_predict_scaled = lstm.predict(X_train)
test_predict_scaled = lstm.predict(X_test)

train_ic = spearmanr(y_train, train_predict_scaled)[0]
test_ic = spearmanr(y_test, test_predict_scaled)[0]
print(f"Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Train IC: 0.9882 | Test IC: 0.9933

# %%
train_predict = pd.Series(scaler.inverse_transform(train_predict_scaled).squeeze(), index=y_train.index)
test_predict = (pd.Series(scaler.inverse_transform(test_predict_scaled).squeeze(), index=y_test.index))
# use inverse_transform to convert the scaled data back to its original scale.
y_train_rescaled = scaler.inverse_transform(y_train.to_frame()).squeeze()
y_test_rescaled = scaler.inverse_transform(y_test.to_frame()).squeeze()

# %%
train_rmse = np.sqrt(mean_squared_error(train_predict, y_train_rescaled))
test_rmse = np.sqrt(mean_squared_error(test_predict, y_test_rescaled))
print(f"Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}")
# Out:
# Train RMSE: 0.74 | Test RMSE: 3.31

# %%
stock_price['Train Predictions'] = train_predict
stock_price['Test Predictions'] = test_predict

to_be_merged = pd.concat([train_predict.to_frame('predictions').assign(data='Train'),
                   test_predict.to_frame('predictions').assign(data='Test')])

stock_price = pd.merge(stock_price, to_be_merged, how='inner', on='Date')
stock_price.columns = stock_price.columns.str.rstrip('_x').str.rstrip('_y')

# %%
stock_price
# Out:
#              Adj Close  Train Predictions  Test Predictions  predictions  \
# Date
# 2020-03-30    6.616442           6.277786               NaN     6.277786
# 2020-03-31    6.566867           6.429833               NaN     6.429833
# 2020-04-01    6.055418           6.537471               NaN     6.537471
# 2020-04-02    6.364330           6.509201               NaN     6.509201
# 2020-04-03    6.076344           6.550087               NaN     6.550087
# ...                ...                ...               ...          ...
# 2024-08-26  126.449181                NaN        131.240768   131.240768
# 2024-08-27  128.289032                NaN        128.153625   128.153625
# 2024-08-28  125.599258                NaN        126.226311   126.226311
# 2024-08-29  117.579941                NaN        123.619926   123.619926
# 2024-08-30  119.359795                NaN        118.207436   118.207436
#
#              data
# Date
# 2020-03-30  Train
# 2020-03-31  Train
# 2020-04-01  Train
# 2020-04-02  Train
# 2020-04-03  Train
# ...           ...
# 2024-08-26   Test
# 2024-08-27   Test
# 2024-08-28   Test
# 2024-08-29   Test
# 2024-08-30   Test
#
# [1114 rows x 5 columns]

# %%
fig=plt.figure(figsize=(14,7))
ax1 = plt.subplot(221)
stock_price.loc['2020':, price_type].plot(lw=2, ax=ax1, c='k')
stock_price.loc['2020':, ['Test Predictions', 'Train Predictions']].plot(lw=1, ax=ax1, ls='--')
ax1.set_title('In- and Out-of-sample Predictions')

with sns.axes_style("white"):
    ax3 = plt.subplot(223)
    sns.scatterplot(x = price_type, y = 'predictions', data = stock_price, hue = 'data', ax = ax3)
    ax3.text(x=.02, y=.95, s=f'Test IC ={test_ic:.2%}', transform=ax3.transAxes)
    ax3.text(x=.02, y=.87, s=f'Train IC={train_ic:.2%}', transform=ax3.transAxes)
    ax3.set_title('Correlation')
    ax3.legend(loc='lower right')

    ax2 = plt.subplot(222)
    ax4 = plt.subplot(224, sharex = ax2, sharey=ax2)
    sns.distplot(train_predict.squeeze()- y_train_rescaled, ax=ax2)
    ax2.set_title('Train Error')
    ax2.text(x=.03, y=.92, s=f'Train RMSE = ${train_rmse:.4f}', transform=ax2.transAxes)
    sns.distplot(test_predict.squeeze()-y_test_rescaled, ax=ax4)
    ax4.set_title('Test Error')
    ax4.text(x=.03, y=.92, s=f'Test RMSE = ${test_rmse:.4f}', transform=ax4.transAxes)

sns.despine()
fig.tight_layout()
